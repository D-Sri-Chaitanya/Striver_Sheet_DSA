# %%
# largest element in an array :
#Brute force:
#1. sort the arr in ascending order.
#2. return last element of the array.

# def largest(nums):
#     for i in range(len(nums)):
#         for j in range(0,len(nums)-i-1):
#             if nums[j] > nums[j+1]:
#                 nums[j],nums[j+1] = nums[j+1],nums[j]
#     return nums[len(nums)-1]

# nums = list(map(int,input("Enter array Elements: ").split()))
# print(largest(nums))
#Time complexity = O(n**2)
#Space complexity = O(1)


# optimal approach:
 
# 1.Create a variable called max and initialize it with the value of the first element in the array.
# 2.Use a for loop to iterate through the rest of the elements in the array.
# 3.In each iteration, compare the current element with the max variable.
# 4.If the current element is greater than the max value, update the max value with the current element's value.
# 5.After completing the loop, print the max variable, which will hold the largest value in the array.

def largest(nums):
    large = nums[0]
    for i in range(len(nums)):
        if nums[i] > large:
            large = nums[i]
    return large

nums = list(map(int,input("Enter array Elements: ").split()))
print(largest(nums))
#Time complexity = O(n)
#Space complexity = O(1)
# Out:
# 8

# %%
#second smallest and second largest element in the arr:
#Brute force approach:

#Algorithm: Find the Second Largest Element in an Array (Brute Force)
# Step 1: Sort the array in ascending order.
# Step 2: Check the length of the array.if the length of the array is 1, return arr[0],arr[0].
# Step 3: If the length of the array is 2, return arr[0] and arr[1].
# Step 4: Convert the array into a set to remove duplicate elements.arr = sorted(set(arr))
# Step 5: Check the length of the array after removing duplicates.If the length is 1, return arr[0] and arr[0].
# Step 6: Otherwise, return arr[-2] as the second largest element.

# def second_largest_smallest(nums):
#     nums.sort()
#     if len(nums) == 1:
#         return nums[0] , nums[0]
#     elif len(nums) == 2:
#         return nums[0] , nums[1]
#     else:
#         nums = sorted(set(nums))
#         if len(nums) == 1:
#             return nums[0],nums[0]
#         return nums[1], nums[-1]
# nums = list(map(int,input("Enter array Elements: ").split()))
# print(second_largest_smallest(nums))
#Time complexity = O(nlogn)
#Space complexity = O(n)

#optimized approach:
#Algorithm:
# 1.We will need four variables: small, second_small, large, and second_large. Initialize small and second_small to inf, and large and second_large to -inf.
# 2.Second Smallest Algorithm: 
# 2.1 If the current element is smaller than 'small', update the values of second_small and small.
# 2.2 Else if the current element is smaller than 'second_small', update the value of second_small.
# 2.3 After traversing the array, the second smallest element will be stored in the variable second_small.
# 3. Second Largest Algorithm:
# 3.1 If the current element is larger than 'large', update the values of second_large and large.
# 3.2 Else if the current element is larger than 'second_large', update the value of second_large.
# 3.3 After traversing the array, the second largest element will be stored in the variable second_large.
def second_largest_smallest(nums):
    small = float('inf')
    second_small = float('inf')
    large = float('-inf')
    second_large = float('-inf')

    for num in nums:
        if num < small:
            second_small = small
            small = num
        elif num < second_small and num != small:
            second_small = num
        if num > large:
            second_large = large
            large = num
        elif num > second_large and num != large:
            second_large = num
    return second_small,second_large

nums = list(map(int,input("Enter array Elements: ").split()))
print(second_largest_smallest(nums))
#Time complexity = O(n)
#Space complexity = O(1)
# Out:
# (3, 5)

# %%
#check if array is sorted II:
#Brute force:
#Algorithm:
# Check if Array is Sorted and Rotated (Brute Force)
# Step 1: Read the array nums.
# Step 2: Let n be the length of the array.
# Step 3: Repeat the following steps for each possible rotation from 0 to n−1:
#     a) Assume the array is sorted.
#        Set is_sorted = True.
#     b) Traverse the array from index i = 0 to n−2.
#     c) If nums[i] > nums[i+1], then the array is not sorted.
#        Set is_sorted = False and break the loop.
#     d) If is_sorted remains True after the traversal,
#        return True because a sorted rotation exists.
#     e) Rotate the array by one position to the right:
#        nums = [nums[-1]] + nums[:-1]
# Step 4: If no rotation produces a sorted array,
# return False.

# def check_sorted(nums):
#     for rotation in range(len(nums)):
#         sorted = True
#         for i in range(len(nums)-1):
#             if nums[i] > nums[i+1]:
#                 sorted = False
#                 break
#         if sorted:
#             return True
#         nums = [nums[-1]]+nums[:-1]
#     return False

# nums = list(map(int,input("Enter array Elements: ").split()))
# print(check_sorted(nums))

#optimized:
#algorithm:
# Check if an Array is Sorted and Rotated
# Step 1: Let n be the length of the array.
# Step 2: Initialize a variable count = 0.
# Step 3: Traverse the array from i = 0 to n-1.
# Step 4: For each index i, compare the current element with the next element using circular indexing:
# If nums[i] > nums[(i + 1) % n], increment count by 1.
# Step 5: After completing the traversal, check the value of count.
# Step 6: If count is less than or equal to 1, return True because the array is sorted and rotated.
# Step 7: Otherwise, return False because the array is not sorted and rotated.

def check_sorted(nums):
    drops = 0
    for i in range(len(nums)):
        if nums[i] > nums[(i+1)%len(nums)]:
            drops += 1
    if drops == 0 or drops == 1:
        return True
    else:
        return False  

nums = list(map(int,input("Enter array Elements: ").split()))
print(check_sorted(nums))
#Time complexity = O(n)
#Space complexity = O(1)
# Out:
# True

# %%
#Remove duplicates from the sorted array:
#Brute force:
# Algorithm: Remove Duplicates from a Sorted Array
# Step 1: Start.
# Step 2: Create an empty list called unique.
# Step 3: Insert the first element of the array nums into the list unique.
# Step 4: Traverse the array from index 1 to length(nums) - 1.
# Step 5: For each element nums[i], compare it with the previous element nums[i-1].
# Step 6: If nums[i] is not equal to nums[i-1], append nums[i] to the unique list.
# Step 7: Repeat Steps 5 and 6 until the loop ends
# Step 8: Return the length of the unique list.
# Step 9: End.

# def remove_duplicates(nums):
#     unique = []
#     unique.append(nums[0])
#     for i in range(1,len(nums)):
#         if nums[i] != nums[i-1]:
#             unique.append(nums[i])
#     return len(unique)

# nums = list(map(int,input("Enter array Elements: ").split()))
# print(remove_duplicates(nums))
#Time complexity = O(n)
#Space complexity = O(n)

#optimal approach:
# Algorithm: Remove Duplicates from a Sorted Array (Optimal – Two Pointer)
# Step 1: Start.
# Step 2: Initialize a variable k = 1 to track the position of the next unique element.
# Step 3: Traverse the array from index 1 to length(nums) - 1.
# Step 4: For each element nums[i], compare it with the previous element nums[i-1].
# Step 5: If nums[i] is not equal to nums[i-1], place nums[i] at index k in the array.
# Step 6: Increment k by 1.
# Step 7: Repeat Steps 4–6 until the loop finishes.
# Step 8: Return k, which represents the number of unique elements.
# Step 9: End.

def remove_duplicates(nums):
    k = 1
    for i in range(1,len(nums)):
        if nums[i] != nums[i-1]:
            nums[k] = nums[i]
            k += 1
    return k

nums = list(map(int,input("Enter array Elements: ").split()))
print(remove_duplicates(nums))
#Time complexity = O(n)
#Space complexity = O(1)
# Out:
# 3

# %%
# left rotate array by k places:
#Brute force:
#Algorithm:
# Step 1: Start.
# Step 2: Repeat the following steps k times.
# Step 3: Store the last element of the array in a variable temp.
# Step 4: Shift every element of the array one position to the right.
# Step 5: Place temp at index 0.
# Step 6: Repeat until k rotations are completed.
# Step 7: End.

# def rotate(nums,k):
#     n = len(nums)
#     for i in range(k):
#         last = nums[-1]
#         for i in range(n-1,0,-1):
#             nums[i] = nums[i-1]
#         nums[0] = last
#     return nums

# nums = list(map(int,input().split()))
# k = int(input())
# print(rotate(nums,k))
#Time complexity = O(n*k)
#Space complexity = O(1)

#optimal:
# Algorithm: Rotate Array using Reverse Method
# Step 1: Start.
# Step 2: Read the array nums and the integer k.
# Step 3: Find the length of the array n.
# Step 4: Compute k = k mod n.
# Step 5: Reverse the entire array from index 0 to n-1.
# Step 6: Reverse the first k elements of the array from index 0 to k-1.
# Step 7: Reverse the remaining elements from index k to n-1.
# Step 8: Print or return the rotated array.
# Step 9: End.

def reverse(nums,start,end):
    while start < end:
        nums[start],nums[end] = nums[end],nums[start]
        start += 1
        end -= 1
    return nums

def rotate(nums,k):
    n = len(nums)
    k = k%n
    reverse(nums,0,n-1)
    reverse(nums,0,k-1)
    reverse(nums,k,n-1)
    return nums

nums = list(map(int,input().split()))
k = int(input())
print(rotate(nums,k))
#Time complexity = O(n)
#Space complexity = O(1)
# Out:
# [5, 6, 7, 1, 2, 3, 4]

# %%
#move zeroes to end :
#Brute force:
# Algorithm: Move Zeroes to End (Brute Force)
# Step 1: Start
# Step 2: Input array nums
# Step 3: Create an empty list non_zero
# Step 4: Initialize count = 0
# Step 5: For i from 0 to length(nums) - 1
#             If nums[i] is not equal to 0
#                 Append nums[i] to non_zero
#             Else
#                 Increment count by 1
#         End For
# Step 6: For i from 0 to count - 1
#             Append 0 to non_zero
#         End For
# Step 7: Return non_zero
# Step 8: End

# def move(nums):
#     non_zero = []
#     count = 0
#     for i in range(len(nums)):
#         if nums[i] != 0:
#             non_zero.append(nums[i])
#         else:
#             count += 1
#     for i in range(count):
#         non_zero.append(0)
#     return non_zero 

# nums = list(map(int,input().split()))
# print(move(nums))
#Time complexity = O(n)
#Space complexity = O(n)

#optimized:
# Algorithm: Move Zeroes to End (Optimal Two Pointer Approach)
# Step 1: Start
# Step 2: Input array nums
# Step 3: Find the length of the array n
# Step 4: Initialize pointer k = 0
# Step 5: Traverse the array from i = 0 to n-1
#             If nums[i] is not equal to 0
#                 Swap nums[k] and nums[i]
#                 Increment k by 1
#         End For
# Step 6: Return nums
# Step 7: End

def move(nums):
    n = len(nums)
    k = 0
    for i in range(n):
        if nums[i] != 0:
            nums[k],nums[i] = nums[i] , nums[k]
            k+=1
    return nums

nums = list(map(int,input().split()))
print(move(nums))
#Time complexity = O(n)
#Space complexity = O(1)
# Out:
# [1, 2, 5, 4, 0, 0]

# %%
#linear search:
# Algorithm LinearSearch(arr, n, key)
# 1. Start
# 2. For i ← 0 to n-1 do
# 3.     If arr[i] == key then
# 4.         return i
# 5. End For
# 6. return -1
# 7. Stop

def linear_search(nums, key):
    for i in range(len(nums)):
        if nums[i] == key:
            return i
    return -1

nums = list(map(int,input().split()))
key = int(input())
print(linear_search(nums,key))
#Time complexity = O(n)
#Space complexity = O(1)
# Out:
# 2

# %%
#Max consecutive ones:
#Brute force:
#Algorithm:
# 1. Initialize an empty list count
# 2. Initialize max_ones = 0
# 3. Traverse the array from index 0 to n-1
# 4. If nums[i] == 1
#         Increase max_ones by 1
# 5. Else
#         Append max_ones to count
#         Reset max_ones = 0
# 6. After loop ends, append max_ones to count
#    (to store the last sequence of 1s)
# 7. Return the maximum value from count

def findMaxConsecutiveOnes(self, nums):
    count = []
    max_ones = 0
    for i in range(len(nums)):
        if nums[i] == 1:
            max_ones += 1
        else:
            count.append(max_ones)
            max_ones = 0
    count.append(max_ones)   
    return max(count)
#Time complexity = O(n)
#Space complexity = O(n)

#optimized :
# Algorithm: Find Maximum Consecutive Ones
# Step 1: Start
# Step 2: Define function findMaxConsecutiveOnes(nums)
# Step 3: Initialize
#         count = 0
#         max_count = 0
# Step 4: For i from 0 to length(nums) - 1
# Step 5: If nums[i] == 1
#             count = count + 1
#             max_count = max(max_count, count)
# Step 6: Else
#             count = 0
# Step 7: End For loop
# Step 8: Return max_count
# Step 9: Take input array from user
# Step 10: Call function findMaxConsecutiveOnes(nums)
# Step 11: Print the result
# Step 12: Stop

def findMaxConsecutiveOnes(nums):
    count = 0
    max_count = 0
    for i in range(len(nums)):
        if nums[i] == 1:
            count += 1
            max_count = max(max_count,count)
        else:
            count  = 0
    return max_count
            
nums = list(map(int,input().split()))
print(findMaxConsecutiveOnes(nums))
#Time complexity = O(n)
#Space complexity = O(1)
# Out:
# 3
